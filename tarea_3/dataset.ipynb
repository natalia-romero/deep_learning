# %%
import os
import pandas as pd
import torchaudio
import librosa
import numpy as np
import soundfile as sf
from pydub import AudioSegment

# %%
def convert_webm_to_wav(webm_path, wav_path):
    audio = AudioSegment.from_file(webm_path, format='webm')
    audio = audio.set_channels(1)  # Convert to mono
    audio.export(wav_path, format='wav')

# %%
train = pd.read_csv('/kaggle/input/udp-dl-trabajo-3-covid-19/train.csv')
test = pd.read_csv('/kaggle/input/udp-dl-trabajo-3-covid-19/test.csv')
#samples = train.drop(columns=["covid"])

# %%
max_duration = 0
audio_durations = {}

# %%
def process_audio_files(csv_file):
    data = pd.read_csv(csv_file)
    #samples = data.drop(columns=["covid"])
    samples = data
    max_duration = 0
    audio_durations = {}
    
    for index, row in samples.iterrows():
        print(f"INDEX {index} - Processing UUID: {row['uuid']}")
        webm_path = f'/kaggle/input/udp-dl-trabajo-3-covid-19/audio/{row["uuid"]}.webm'
        wav_path = f'/kaggle/working/{row["uuid"]}.wav'
        print(webm_path, wav_path)
        if os.path.exists(webm_path):
            convert_webm_to_wav(webm_path, wav_path)
        elif os.path.exists(webm_path.replace('.webm', '.wav')):
            wav_path = webm_path.replace('.webm', '.wav')
        else:
            print(f"Audio file for UUID {row['uuid']} not found.")
            continue

        duration = librosa.get_duration(path=wav_path)
        audio_durations[row['uuid']] = (wav_path, duration)
        if duration > max_duration:
            max_duration = duration
        print(f"Duration of {row['uuid']}: {duration:.2f} seconds")
    
    return audio_durations, max_duration

# %%
#no puedo ejecutar los audios de train y test al mismo tiempo ya q la memoria muere asi que por eso estan comentados los de train pq ejecuté por ultima vez los de test
#train_audio_durations, train_max_duration = process_audio_files('/kaggle/input/udp-dl-trabajo-3-covid-19/train.csv')¿
#test_audio_durations, test_max_duration = process_audio_files('/kaggle/input/udp-dl-trabajo-3-covid-19/test.csv')

# %%
#aca se busca el audio mas grande entre test y train para agregarle padding dps a los mas cortos 
#overall_max_duration = max(19.74, test_max_duration)
#overall_max_duration = max(train_max_duration, 0)
#overall_max_duration = max(train_max_duration, test_max_duration)
#print(f"Overall maximum duration: {overall_max_duration:.2f} seconds")

# %%
def pad_audio_files(audio_durations, max_duration):
    for uuid, (wav_path, duration) in audio_durations.items():
        if duration < max_duration:
            waveform, sample_rate = torchaudio.load(wav_path)
            padding = int((max_duration - duration) * sample_rate)
            padded_waveform = np.pad(waveform.numpy(), ((0, 0), (0, padding)), mode='constant')
            sf.write(wav_path, padded_waveform.T, sample_rate)
            print(f"Padded {uuid} to {max_duration:.2f} seconds")
        else:
            print(f"No padding needed for {uuid}")

# %%
#pad_audio_files(train_audio_durations, overall_max_duration)
#pad_audio_files(test_audio_durations, overall_max_duration)

#print("All audio files have been padded to the maximum duration.")

# %%
# !pip install torchaudio matplotlib
# Out:
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.1.2+cpu)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (3.7.5)
# Requirement already satisfied: torch==2.1.2 in /opt/conda/lib/python3.10/site-packages (from torchaudio) (2.1.2+cpu)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch==2.1.2->torchaudio) (2024.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch==2.1.2->torchaudio) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch==2.1.2->torchaudio) (1.3.0)

# %%
import torchaudio
import torch
import matplotlib.pyplot as plt

# %%
def audio_to_mel_spectrogram(audio_path):
    waveform, sample_rate = torchaudio.load(audio_path)
    
    # Crear el transformador de mel-espectrograma
    mel_spectrogram = torchaudio.transforms.MelSpectrogram(
        sample_rate=sample_rate,
        n_mels=64
    )(waveform)
    
    # Convertir a escala logarítmica
    mel_spectrogram = torchaudio.transforms.AmplitudeToDB()(mel_spectrogram)
    
    return mel_spectrogram

# %%
def process_and_save_mel_spectrograms(audio_durations, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    for uuid, (wav_path, _) in audio_durations.items():
        try:
            mel_spectrogram = audio_to_mel_spectrogram(wav_path)
            output_path = os.path.join(output_dir, f"{uuid}.pt")
            torch.save(mel_spectrogram, output_path)
            print(f"Saved mel-spectrogram for {uuid} at {output_path}")
            
            # Eliminar el archivo de audio después de procesarlo
            os.remove(wav_path)
            print(f"Deleted audio file for {uuid} at {wav_path}")
        except Exception as e:
            print(f"Error processing {uuid}: {e}")

# %%
#output_dir_train = '/kaggle/working/mel_spectrograms/train'
#output_dir_test = '/kaggle/working/mel_spectrograms/test'

# %%
#process_and_save_mel_spectrograms(train_audio_durations, output_dir_train)
#process_and_save_mel_spectrograms(test_audio_durations, output_dir_test)
print("All mel-spectrograms have been saved.")
# Out:
# All mel-spectrograms have been saved.

# %%
import random
def load_random_mel_spectrograms(spectrogram_dir, num_samples=3):
    all_files = [f for f in os.listdir(spectrogram_dir) if f.endswith('.pt')]
    
    random_files = random.sample(all_files, num_samples)
    
    mel_spectrograms = [torch.load(os.path.join(spectrogram_dir, f)) for f in random_files]
    
    return mel_spectrograms, random_files

# %%
#spectrogram_dir = '/kaggle/working/mel_spectrograms/augmented_train'

# %%
#mel_spectrograms, random_files = load_random_mel_spectrograms(spectrogram_dir, num_samples=3)

# %%
def plot_mel_spectrograms(mel_spectrograms, filenames):
    for i, (mel_spectrogram, filename) in enumerate(zip(mel_spectrograms, filenames)):
        plt.figure(figsize=(10, 4))
        plt.imshow(mel_spectrogram.squeeze().numpy(), cmap='viridis', origin='lower', aspect='auto')
        plt.colorbar(format='%+2.0f dB')
        plt.title(f'Mel-Spectrogram (dB) - {filename}')
        plt.xlabel('Time')
        plt.ylabel('Frequency')
        plt.show()

#plot_mel_spectrograms(mel_spectrograms, random_files)

# %%
import zipfile
import os

def zip_directory(directory_path, output_zip):
    with zipfile.ZipFile(output_zip, 'w') as zipf:
        for root, _, files in os.walk(directory_path):
            for file in files:
                zipf.write(os.path.join(root, file),
                           os.path.relpath(os.path.join(root, file),
                           os.path.join(directory_path, '..')))

#output_dir_train = '/kaggle/working/mel_spectrograms/train'
#output_dir_test = '/kaggle/working/mel_spectrograms/test'
#output_zip_train = '/kaggle/working/mel_spectrograms_train.zip'
#output_zip_test = '/kaggle/working/mel_spectrograms_test.zip'

#zip_directory(output_dir_train, output_zip_train)
#zip_directory(output_dir_test, output_zip_test)

#print(f"Train mel-spectrograms zipped to: {output_zip_train}")
#print(f"Test mel-spectrograms zipped to: {output_zip_test}")

# %% [markdown]
# ## augmentation
# solo de clase covid (1) pq hay 500 muestras vs >6000 de no covid. eso es malo pq el entrenamiento esta muuy sesgado a no covid, y aunque se aumente los no covid quedará tambien sesgado a ese tipo de tos de covid

# %%
# Filtrar los datos con etiqueta COVID (1)
covid_data = train[train['covid'] == 1]

# %%
spectrogram_dir_train = '/kaggle/input/mel-train/train'

# %%
covid_files = [os.path.join(spectrogram_dir_train, f"{uuid}.pt") for uuid in covid_data['uuid'] if os.path.exists(os.path.join(spectrogram_dir_train, f"{uuid}.pt"))]

# %%
print(f"Found {len(covid_files)} COVID-19 mel-spectrograms for augmentation.")
# Out:
# Found 487 COVID-19 mel-spectrograms for augmentation.

# %%
class MelSpectrogramAugmentation:
    def __init__(self, max_noise=0.1, max_gain=0.1):
        self.max_noise = max_noise
        self.max_gain = max_gain

    def __call__(self, mel_spectrogram):
        if random.random() > 0.5:
            mel_spectrogram = mel_spectrogram + (torch.randn_like(mel_spectrogram) * self.max_noise)
        if random.random() > 0.5:
            gain = random.uniform(1.0 - self.max_gain, 1.0 + self.max_gain)
            mel_spectrogram = mel_spectrogram * gain
        return mel_spectrogram

# %%
augment_transform = MelSpectrogramAugmentation()

# %%
augmented_dir_train = '/kaggle/working/mel_spectrograms/augmented_train'
os.makedirs(augmented_dir_train, exist_ok=True)

# %%
for file_path in covid_files:
    mel_spectrogram = torch.load(file_path)
    for i in range(7):  #4 augmentations
        augmented_spectrogram = augment_transform(mel_spectrogram)
        augmented_uuid = f"{os.path.splitext(os.path.basename(file_path))[0]}_aug_{i}.pt"
        augmented_path = os.path.join(augmented_dir_train, augmented_uuid)
        torch.save(augmented_spectrogram, augmented_path)
        print(f"Saved augmented mel-spectrogram at {augmented_path}")
# Out:
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3db14b07-2720-4fa9-870a-725fda24a0bd_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3db14b07-2720-4fa9-870a-725fda24a0bd_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3db14b07-2720-4fa9-870a-725fda24a0bd_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3db14b07-2720-4fa9-870a-725fda24a0bd_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3db14b07-2720-4fa9-870a-725fda24a0bd_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3db14b07-2720-4fa9-870a-725fda24a0bd_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3db14b07-2720-4fa9-870a-725fda24a0bd_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5e9a1af-2571-40f7-99c7-77cfe71657c5_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5e9a1af-2571-40f7-99c7-77cfe71657c5_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5e9a1af-2571-40f7-99c7-77cfe71657c5_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5e9a1af-2571-40f7-99c7-77cfe71657c5_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5e9a1af-2571-40f7-99c7-77cfe71657c5_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5e9a1af-2571-40f7-99c7-77cfe71657c5_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5e9a1af-2571-40f7-99c7-77cfe71657c5_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afd37003-52a9-44ba-bcf4-7fc7d637ad37_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afd37003-52a9-44ba-bcf4-7fc7d637ad37_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afd37003-52a9-44ba-bcf4-7fc7d637ad37_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afd37003-52a9-44ba-bcf4-7fc7d637ad37_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afd37003-52a9-44ba-bcf4-7fc7d637ad37_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afd37003-52a9-44ba-bcf4-7fc7d637ad37_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afd37003-52a9-44ba-bcf4-7fc7d637ad37_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b95b4d94-e665-41d0-bd0e-4fb9d4684e65_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b95b4d94-e665-41d0-bd0e-4fb9d4684e65_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b95b4d94-e665-41d0-bd0e-4fb9d4684e65_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b95b4d94-e665-41d0-bd0e-4fb9d4684e65_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b95b4d94-e665-41d0-bd0e-4fb9d4684e65_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b95b4d94-e665-41d0-bd0e-4fb9d4684e65_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b95b4d94-e665-41d0-bd0e-4fb9d4684e65_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f6dc7637-6214-4f47-9063-3cbfb8b3b519_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f6dc7637-6214-4f47-9063-3cbfb8b3b519_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f6dc7637-6214-4f47-9063-3cbfb8b3b519_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f6dc7637-6214-4f47-9063-3cbfb8b3b519_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f6dc7637-6214-4f47-9063-3cbfb8b3b519_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f6dc7637-6214-4f47-9063-3cbfb8b3b519_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f6dc7637-6214-4f47-9063-3cbfb8b3b519_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4cd64634-5414-455d-9458-d497abe62b0f_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4cd64634-5414-455d-9458-d497abe62b0f_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4cd64634-5414-455d-9458-d497abe62b0f_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4cd64634-5414-455d-9458-d497abe62b0f_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4cd64634-5414-455d-9458-d497abe62b0f_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4cd64634-5414-455d-9458-d497abe62b0f_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4cd64634-5414-455d-9458-d497abe62b0f_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/96678e97-6a39-4932-9c5d-13981167bbd8_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/96678e97-6a39-4932-9c5d-13981167bbd8_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/96678e97-6a39-4932-9c5d-13981167bbd8_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/96678e97-6a39-4932-9c5d-13981167bbd8_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/96678e97-6a39-4932-9c5d-13981167bbd8_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/96678e97-6a39-4932-9c5d-13981167bbd8_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/96678e97-6a39-4932-9c5d-13981167bbd8_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a75adc66-7f70-4f0f-91f7-7a2a2eac61e9_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a75adc66-7f70-4f0f-91f7-7a2a2eac61e9_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a75adc66-7f70-4f0f-91f7-7a2a2eac61e9_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a75adc66-7f70-4f0f-91f7-7a2a2eac61e9_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a75adc66-7f70-4f0f-91f7-7a2a2eac61e9_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a75adc66-7f70-4f0f-91f7-7a2a2eac61e9_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a75adc66-7f70-4f0f-91f7-7a2a2eac61e9_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/58970bd3-2993-4762-8b21-0c5a2937c16b_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/58970bd3-2993-4762-8b21-0c5a2937c16b_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/58970bd3-2993-4762-8b21-0c5a2937c16b_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/58970bd3-2993-4762-8b21-0c5a2937c16b_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/58970bd3-2993-4762-8b21-0c5a2937c16b_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/58970bd3-2993-4762-8b21-0c5a2937c16b_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/58970bd3-2993-4762-8b21-0c5a2937c16b_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/14c7b709-ac4d-4aee-bdbc-ac51c11a497e_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/14c7b709-ac4d-4aee-bdbc-ac51c11a497e_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/14c7b709-ac4d-4aee-bdbc-ac51c11a497e_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/14c7b709-ac4d-4aee-bdbc-ac51c11a497e_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/14c7b709-ac4d-4aee-bdbc-ac51c11a497e_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/14c7b709-ac4d-4aee-bdbc-ac51c11a497e_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/14c7b709-ac4d-4aee-bdbc-ac51c11a497e_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ecc957af-3001-4a29-935a-32db98540746_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ecc957af-3001-4a29-935a-32db98540746_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ecc957af-3001-4a29-935a-32db98540746_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ecc957af-3001-4a29-935a-32db98540746_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ecc957af-3001-4a29-935a-32db98540746_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ecc957af-3001-4a29-935a-32db98540746_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ecc957af-3001-4a29-935a-32db98540746_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/28757e31-b8f6-408c-982e-a016170ab3ef_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/28757e31-b8f6-408c-982e-a016170ab3ef_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/28757e31-b8f6-408c-982e-a016170ab3ef_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/28757e31-b8f6-408c-982e-a016170ab3ef_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/28757e31-b8f6-408c-982e-a016170ab3ef_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/28757e31-b8f6-408c-982e-a016170ab3ef_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/28757e31-b8f6-408c-982e-a016170ab3ef_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5d1fff93-65cd-49dd-b9d4-3303e350b546_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5d1fff93-65cd-49dd-b9d4-3303e350b546_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5d1fff93-65cd-49dd-b9d4-3303e350b546_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5d1fff93-65cd-49dd-b9d4-3303e350b546_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5d1fff93-65cd-49dd-b9d4-3303e350b546_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5d1fff93-65cd-49dd-b9d4-3303e350b546_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5d1fff93-65cd-49dd-b9d4-3303e350b546_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6868da77-a36a-4fb4-afa5-aba26bd2bbd5_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6868da77-a36a-4fb4-afa5-aba26bd2bbd5_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6868da77-a36a-4fb4-afa5-aba26bd2bbd5_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6868da77-a36a-4fb4-afa5-aba26bd2bbd5_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6868da77-a36a-4fb4-afa5-aba26bd2bbd5_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6868da77-a36a-4fb4-afa5-aba26bd2bbd5_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6868da77-a36a-4fb4-afa5-aba26bd2bbd5_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8b59b5d8-78bc-4654-b0ed-895480d38449_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8b59b5d8-78bc-4654-b0ed-895480d38449_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8b59b5d8-78bc-4654-b0ed-895480d38449_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8b59b5d8-78bc-4654-b0ed-895480d38449_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8b59b5d8-78bc-4654-b0ed-895480d38449_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8b59b5d8-78bc-4654-b0ed-895480d38449_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8b59b5d8-78bc-4654-b0ed-895480d38449_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/46c6c8ef-8b3d-42a1-b4a1-e86e6aeb1664_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/46c6c8ef-8b3d-42a1-b4a1-e86e6aeb1664_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/46c6c8ef-8b3d-42a1-b4a1-e86e6aeb1664_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/46c6c8ef-8b3d-42a1-b4a1-e86e6aeb1664_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/46c6c8ef-8b3d-42a1-b4a1-e86e6aeb1664_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/46c6c8ef-8b3d-42a1-b4a1-e86e6aeb1664_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/46c6c8ef-8b3d-42a1-b4a1-e86e6aeb1664_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afadbd6d-433c-4ffc-81da-1f0217bac43e_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afadbd6d-433c-4ffc-81da-1f0217bac43e_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afadbd6d-433c-4ffc-81da-1f0217bac43e_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afadbd6d-433c-4ffc-81da-1f0217bac43e_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afadbd6d-433c-4ffc-81da-1f0217bac43e_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afadbd6d-433c-4ffc-81da-1f0217bac43e_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/afadbd6d-433c-4ffc-81da-1f0217bac43e_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5b0be374-28d0-4a16-b010-0c18a460a7d4_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5b0be374-28d0-4a16-b010-0c18a460a7d4_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5b0be374-28d0-4a16-b010-0c18a460a7d4_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5b0be374-28d0-4a16-b010-0c18a460a7d4_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5b0be374-28d0-4a16-b010-0c18a460a7d4_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5b0be374-28d0-4a16-b010-0c18a460a7d4_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5b0be374-28d0-4a16-b010-0c18a460a7d4_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dc994f21-ea5e-4236-bc48-2fd980feb2f8_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dc994f21-ea5e-4236-bc48-2fd980feb2f8_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dc994f21-ea5e-4236-bc48-2fd980feb2f8_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dc994f21-ea5e-4236-bc48-2fd980feb2f8_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dc994f21-ea5e-4236-bc48-2fd980feb2f8_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dc994f21-ea5e-4236-bc48-2fd980feb2f8_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dc994f21-ea5e-4236-bc48-2fd980feb2f8_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc6f669-469e-4306-acdc-f46039006148_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc6f669-469e-4306-acdc-f46039006148_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc6f669-469e-4306-acdc-f46039006148_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc6f669-469e-4306-acdc-f46039006148_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc6f669-469e-4306-acdc-f46039006148_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc6f669-469e-4306-acdc-f46039006148_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc6f669-469e-4306-acdc-f46039006148_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/08d5d346-6219-4e6d-ac06-ef489f2d186c_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/08d5d346-6219-4e6d-ac06-ef489f2d186c_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/08d5d346-6219-4e6d-ac06-ef489f2d186c_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/08d5d346-6219-4e6d-ac06-ef489f2d186c_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/08d5d346-6219-4e6d-ac06-ef489f2d186c_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/08d5d346-6219-4e6d-ac06-ef489f2d186c_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/08d5d346-6219-4e6d-ac06-ef489f2d186c_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0379c586-c500-483c-83a6-95b63afe6931_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0379c586-c500-483c-83a6-95b63afe6931_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0379c586-c500-483c-83a6-95b63afe6931_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0379c586-c500-483c-83a6-95b63afe6931_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0379c586-c500-483c-83a6-95b63afe6931_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0379c586-c500-483c-83a6-95b63afe6931_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0379c586-c500-483c-83a6-95b63afe6931_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/56ff4794-4d52-4b89-8e9c-68ab3d8d1a48_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/56ff4794-4d52-4b89-8e9c-68ab3d8d1a48_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/56ff4794-4d52-4b89-8e9c-68ab3d8d1a48_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/56ff4794-4d52-4b89-8e9c-68ab3d8d1a48_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/56ff4794-4d52-4b89-8e9c-68ab3d8d1a48_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/56ff4794-4d52-4b89-8e9c-68ab3d8d1a48_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/56ff4794-4d52-4b89-8e9c-68ab3d8d1a48_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5aa4dae0-fe23-4eb2-9d62-e6016a1c9f8a_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5aa4dae0-fe23-4eb2-9d62-e6016a1c9f8a_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5aa4dae0-fe23-4eb2-9d62-e6016a1c9f8a_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5aa4dae0-fe23-4eb2-9d62-e6016a1c9f8a_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5aa4dae0-fe23-4eb2-9d62-e6016a1c9f8a_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5aa4dae0-fe23-4eb2-9d62-e6016a1c9f8a_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/5aa4dae0-fe23-4eb2-9d62-e6016a1c9f8a_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/1c21cb68-6ea8-4aa1-af22-2e64007554d7_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/1c21cb68-6ea8-4aa1-af22-2e64007554d7_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/1c21cb68-6ea8-4aa1-af22-2e64007554d7_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/1c21cb68-6ea8-4aa1-af22-2e64007554d7_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/1c21cb68-6ea8-4aa1-af22-2e64007554d7_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/1c21cb68-6ea8-4aa1-af22-2e64007554d7_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/1c21cb68-6ea8-4aa1-af22-2e64007554d7_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6d941efe-43f9-4a64-8172-58cbb20400ab_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6d941efe-43f9-4a64-8172-58cbb20400ab_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6d941efe-43f9-4a64-8172-58cbb20400ab_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6d941efe-43f9-4a64-8172-58cbb20400ab_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6d941efe-43f9-4a64-8172-58cbb20400ab_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6d941efe-43f9-4a64-8172-58cbb20400ab_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6d941efe-43f9-4a64-8172-58cbb20400ab_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/658daf16-7fc3-4640-911e-81dac60a2df9_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/658daf16-7fc3-4640-911e-81dac60a2df9_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/658daf16-7fc3-4640-911e-81dac60a2df9_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/658daf16-7fc3-4640-911e-81dac60a2df9_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/658daf16-7fc3-4640-911e-81dac60a2df9_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/658daf16-7fc3-4640-911e-81dac60a2df9_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/658daf16-7fc3-4640-911e-81dac60a2df9_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a0f11dec-e546-4869-a284-cffeeb231c6e_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a0f11dec-e546-4869-a284-cffeeb231c6e_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a0f11dec-e546-4869-a284-cffeeb231c6e_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a0f11dec-e546-4869-a284-cffeeb231c6e_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a0f11dec-e546-4869-a284-cffeeb231c6e_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a0f11dec-e546-4869-a284-cffeeb231c6e_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/a0f11dec-e546-4869-a284-cffeeb231c6e_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e389b2e1-e6a3-4b8d-a6f7-080890003015_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e389b2e1-e6a3-4b8d-a6f7-080890003015_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e389b2e1-e6a3-4b8d-a6f7-080890003015_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e389b2e1-e6a3-4b8d-a6f7-080890003015_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e389b2e1-e6a3-4b8d-a6f7-080890003015_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e389b2e1-e6a3-4b8d-a6f7-080890003015_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e389b2e1-e6a3-4b8d-a6f7-080890003015_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f028405b-2f4f-4379-ba3e-acc7a69f90be_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f028405b-2f4f-4379-ba3e-acc7a69f90be_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f028405b-2f4f-4379-ba3e-acc7a69f90be_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f028405b-2f4f-4379-ba3e-acc7a69f90be_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f028405b-2f4f-4379-ba3e-acc7a69f90be_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f028405b-2f4f-4379-ba3e-acc7a69f90be_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/f028405b-2f4f-4379-ba3e-acc7a69f90be_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6ea6af0c-0f77-46d6-a65b-8df3a925d231_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6ea6af0c-0f77-46d6-a65b-8df3a925d231_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6ea6af0c-0f77-46d6-a65b-8df3a925d231_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6ea6af0c-0f77-46d6-a65b-8df3a925d231_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6ea6af0c-0f77-46d6-a65b-8df3a925d231_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6ea6af0c-0f77-46d6-a65b-8df3a925d231_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6ea6af0c-0f77-46d6-a65b-8df3a925d231_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/abbff660-5d13-4c31-b842-bbf2189ff14e_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/abbff660-5d13-4c31-b842-bbf2189ff14e_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/abbff660-5d13-4c31-b842-bbf2189ff14e_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/abbff660-5d13-4c31-b842-bbf2189ff14e_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/abbff660-5d13-4c31-b842-bbf2189ff14e_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/abbff660-5d13-4c31-b842-bbf2189ff14e_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/abbff660-5d13-4c31-b842-bbf2189ff14e_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc5b8aa6-355a-4f4c-bc88-4f1d5bafc5ad_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc5b8aa6-355a-4f4c-bc88-4f1d5bafc5ad_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc5b8aa6-355a-4f4c-bc88-4f1d5bafc5ad_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc5b8aa6-355a-4f4c-bc88-4f1d5bafc5ad_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc5b8aa6-355a-4f4c-bc88-4f1d5bafc5ad_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc5b8aa6-355a-4f4c-bc88-4f1d5bafc5ad_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc5b8aa6-355a-4f4c-bc88-4f1d5bafc5ad_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/09115490-33a9-461c-9437-d7f71be057b0_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/09115490-33a9-461c-9437-d7f71be057b0_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/09115490-33a9-461c-9437-d7f71be057b0_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/09115490-33a9-461c-9437-d7f71be057b0_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/09115490-33a9-461c-9437-d7f71be057b0_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/09115490-33a9-461c-9437-d7f71be057b0_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/09115490-33a9-461c-9437-d7f71be057b0_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3b917045-a264-4e3c-9a70-491e49448c36_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3b917045-a264-4e3c-9a70-491e49448c36_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3b917045-a264-4e3c-9a70-491e49448c36_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3b917045-a264-4e3c-9a70-491e49448c36_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3b917045-a264-4e3c-9a70-491e49448c36_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3b917045-a264-4e3c-9a70-491e49448c36_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3b917045-a264-4e3c-9a70-491e49448c36_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/40de29df-7881-4cbf-9339-809f6a48ba39_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/40de29df-7881-4cbf-9339-809f6a48ba39_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/40de29df-7881-4cbf-9339-809f6a48ba39_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/40de29df-7881-4cbf-9339-809f6a48ba39_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/40de29df-7881-4cbf-9339-809f6a48ba39_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/40de29df-7881-4cbf-9339-809f6a48ba39_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/40de29df-7881-4cbf-9339-809f6a48ba39_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4fa3ac8d-f252-40d6-bccd-24aa5e35556c_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4fa3ac8d-f252-40d6-bccd-24aa5e35556c_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4fa3ac8d-f252-40d6-bccd-24aa5e35556c_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4fa3ac8d-f252-40d6-bccd-24aa5e35556c_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4fa3ac8d-f252-40d6-bccd-24aa5e35556c_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4fa3ac8d-f252-40d6-bccd-24aa5e35556c_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/4fa3ac8d-f252-40d6-bccd-24aa5e35556c_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/568c58f5-3a30-4166-bc06-b65f06bfcc51_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/568c58f5-3a30-4166-bc06-b65f06bfcc51_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/568c58f5-3a30-4166-bc06-b65f06bfcc51_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/568c58f5-3a30-4166-bc06-b65f06bfcc51_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/568c58f5-3a30-4166-bc06-b65f06bfcc51_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/568c58f5-3a30-4166-bc06-b65f06bfcc51_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/568c58f5-3a30-4166-bc06-b65f06bfcc51_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b74176fe-cc78-4daa-8541-10ba8968439d_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b74176fe-cc78-4daa-8541-10ba8968439d_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b74176fe-cc78-4daa-8541-10ba8968439d_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b74176fe-cc78-4daa-8541-10ba8968439d_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b74176fe-cc78-4daa-8541-10ba8968439d_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b74176fe-cc78-4daa-8541-10ba8968439d_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b74176fe-cc78-4daa-8541-10ba8968439d_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0f8d80f9-700e-4069-924d-e15f29d7c19a_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0f8d80f9-700e-4069-924d-e15f29d7c19a_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0f8d80f9-700e-4069-924d-e15f29d7c19a_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0f8d80f9-700e-4069-924d-e15f29d7c19a_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0f8d80f9-700e-4069-924d-e15f29d7c19a_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0f8d80f9-700e-4069-924d-e15f29d7c19a_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/0f8d80f9-700e-4069-924d-e15f29d7c19a_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/2e4ca5b9-2e1f-4e81-b830-c75ae040dfb4_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/2e4ca5b9-2e1f-4e81-b830-c75ae040dfb4_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/2e4ca5b9-2e1f-4e81-b830-c75ae040dfb4_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/2e4ca5b9-2e1f-4e81-b830-c75ae040dfb4_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/2e4ca5b9-2e1f-4e81-b830-c75ae040dfb4_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/2e4ca5b9-2e1f-4e81-b830-c75ae040dfb4_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/2e4ca5b9-2e1f-4e81-b830-c75ae040dfb4_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e8537e2a-98b1-4ddd-8237-3835215218b4_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e8537e2a-98b1-4ddd-8237-3835215218b4_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e8537e2a-98b1-4ddd-8237-3835215218b4_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e8537e2a-98b1-4ddd-8237-3835215218b4_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e8537e2a-98b1-4ddd-8237-3835215218b4_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e8537e2a-98b1-4ddd-8237-3835215218b4_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e8537e2a-98b1-4ddd-8237-3835215218b4_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2fc880a-7b05-4c36-affe-5ffe03dbc2b4_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2fc880a-7b05-4c36-affe-5ffe03dbc2b4_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2fc880a-7b05-4c36-affe-5ffe03dbc2b4_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2fc880a-7b05-4c36-affe-5ffe03dbc2b4_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2fc880a-7b05-4c36-affe-5ffe03dbc2b4_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2fc880a-7b05-4c36-affe-5ffe03dbc2b4_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2fc880a-7b05-4c36-affe-5ffe03dbc2b4_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d0900d06-18dd-4fa9-94a7-7dc1e4d0f125_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d0900d06-18dd-4fa9-94a7-7dc1e4d0f125_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d0900d06-18dd-4fa9-94a7-7dc1e4d0f125_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d0900d06-18dd-4fa9-94a7-7dc1e4d0f125_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d0900d06-18dd-4fa9-94a7-7dc1e4d0f125_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d0900d06-18dd-4fa9-94a7-7dc1e4d0f125_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d0900d06-18dd-4fa9-94a7-7dc1e4d0f125_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c01b9572-1fbf-463a-9d03-e3857ab5d55a_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c01b9572-1fbf-463a-9d03-e3857ab5d55a_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c01b9572-1fbf-463a-9d03-e3857ab5d55a_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c01b9572-1fbf-463a-9d03-e3857ab5d55a_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c01b9572-1fbf-463a-9d03-e3857ab5d55a_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c01b9572-1fbf-463a-9d03-e3857ab5d55a_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c01b9572-1fbf-463a-9d03-e3857ab5d55a_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/9aea1b03-9fc0-48c9-9e62-a6ac15633c03_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/9aea1b03-9fc0-48c9-9e62-a6ac15633c03_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/9aea1b03-9fc0-48c9-9e62-a6ac15633c03_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/9aea1b03-9fc0-48c9-9e62-a6ac15633c03_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/9aea1b03-9fc0-48c9-9e62-a6ac15633c03_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/9aea1b03-9fc0-48c9-9e62-a6ac15633c03_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/9aea1b03-9fc0-48c9-9e62-a6ac15633c03_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/085c22f5-f9aa-4b42-9c20-59c67baf52a5_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/085c22f5-f9aa-4b42-9c20-59c67baf52a5_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/085c22f5-f9aa-4b42-9c20-59c67baf52a5_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/085c22f5-f9aa-4b42-9c20-59c67baf52a5_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/085c22f5-f9aa-4b42-9c20-59c67baf52a5_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/085c22f5-f9aa-4b42-9c20-59c67baf52a5_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/085c22f5-f9aa-4b42-9c20-59c67baf52a5_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d994f7f6-43cc-445b-8634-ff3c038ffd53_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d994f7f6-43cc-445b-8634-ff3c038ffd53_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d994f7f6-43cc-445b-8634-ff3c038ffd53_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d994f7f6-43cc-445b-8634-ff3c038ffd53_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d994f7f6-43cc-445b-8634-ff3c038ffd53_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d994f7f6-43cc-445b-8634-ff3c038ffd53_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d994f7f6-43cc-445b-8634-ff3c038ffd53_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc83f8b-7906-4534-83d5-f4827287749b_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc83f8b-7906-4534-83d5-f4827287749b_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc83f8b-7906-4534-83d5-f4827287749b_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc83f8b-7906-4534-83d5-f4827287749b_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc83f8b-7906-4534-83d5-f4827287749b_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc83f8b-7906-4534-83d5-f4827287749b_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/dbc83f8b-7906-4534-83d5-f4827287749b_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3ac4c15d-fadd-430f-8866-399b9bd19adc_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3ac4c15d-fadd-430f-8866-399b9bd19adc_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3ac4c15d-fadd-430f-8866-399b9bd19adc_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3ac4c15d-fadd-430f-8866-399b9bd19adc_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3ac4c15d-fadd-430f-8866-399b9bd19adc_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3ac4c15d-fadd-430f-8866-399b9bd19adc_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/3ac4c15d-fadd-430f-8866-399b9bd19adc_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/015576c8-2b03-4dcb-b251-78a984fe86fe_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/015576c8-2b03-4dcb-b251-78a984fe86fe_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/015576c8-2b03-4dcb-b251-78a984fe86fe_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/015576c8-2b03-4dcb-b251-78a984fe86fe_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/015576c8-2b03-4dcb-b251-78a984fe86fe_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/015576c8-2b03-4dcb-b251-78a984fe86fe_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/015576c8-2b03-4dcb-b251-78a984fe86fe_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5908fa3-9410-4f60-ba27-a57cace776ae_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5908fa3-9410-4f60-ba27-a57cace776ae_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5908fa3-9410-4f60-ba27-a57cace776ae_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5908fa3-9410-4f60-ba27-a57cace776ae_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5908fa3-9410-4f60-ba27-a57cace776ae_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5908fa3-9410-4f60-ba27-a57cace776ae_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d5908fa3-9410-4f60-ba27-a57cace776ae_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8fc1ec0d-4d46-4a76-a833-68763de21df1_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8fc1ec0d-4d46-4a76-a833-68763de21df1_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8fc1ec0d-4d46-4a76-a833-68763de21df1_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8fc1ec0d-4d46-4a76-a833-68763de21df1_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8fc1ec0d-4d46-4a76-a833-68763de21df1_aug_4.pt
# ...
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6462d540-48bc-410b-b08e-cdf0b45ee118_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6462d540-48bc-410b-b08e-cdf0b45ee118_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6462d540-48bc-410b-b08e-cdf0b45ee118_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/6462d540-48bc-410b-b08e-cdf0b45ee118_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/33b688eb-cae8-40cb-9d71-694f5d2f417f_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/33b688eb-cae8-40cb-9d71-694f5d2f417f_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/33b688eb-cae8-40cb-9d71-694f5d2f417f_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/33b688eb-cae8-40cb-9d71-694f5d2f417f_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/33b688eb-cae8-40cb-9d71-694f5d2f417f_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/33b688eb-cae8-40cb-9d71-694f5d2f417f_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/33b688eb-cae8-40cb-9d71-694f5d2f417f_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/182246b0-9f77-4c40-976e-3c9342619819_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/182246b0-9f77-4c40-976e-3c9342619819_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/182246b0-9f77-4c40-976e-3c9342619819_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/182246b0-9f77-4c40-976e-3c9342619819_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/182246b0-9f77-4c40-976e-3c9342619819_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/182246b0-9f77-4c40-976e-3c9342619819_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/182246b0-9f77-4c40-976e-3c9342619819_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/aa6fd1f1-ef61-4aba-9db6-18e625736b9f_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/aa6fd1f1-ef61-4aba-9db6-18e625736b9f_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/aa6fd1f1-ef61-4aba-9db6-18e625736b9f_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/aa6fd1f1-ef61-4aba-9db6-18e625736b9f_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/aa6fd1f1-ef61-4aba-9db6-18e625736b9f_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/aa6fd1f1-ef61-4aba-9db6-18e625736b9f_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/aa6fd1f1-ef61-4aba-9db6-18e625736b9f_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e339c45d-998d-4f9b-a8f4-300a63985aa2_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e339c45d-998d-4f9b-a8f4-300a63985aa2_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e339c45d-998d-4f9b-a8f4-300a63985aa2_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e339c45d-998d-4f9b-a8f4-300a63985aa2_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e339c45d-998d-4f9b-a8f4-300a63985aa2_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e339c45d-998d-4f9b-a8f4-300a63985aa2_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/e339c45d-998d-4f9b-a8f4-300a63985aa2_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d70f7518-e3e8-46f3-a4fe-fa43363f16ca_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d70f7518-e3e8-46f3-a4fe-fa43363f16ca_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d70f7518-e3e8-46f3-a4fe-fa43363f16ca_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d70f7518-e3e8-46f3-a4fe-fa43363f16ca_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d70f7518-e3e8-46f3-a4fe-fa43363f16ca_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d70f7518-e3e8-46f3-a4fe-fa43363f16ca_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/d70f7518-e3e8-46f3-a4fe-fa43363f16ca_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52cae2c-3250-45e4-9c3a-4cfb08ef9c98_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52cae2c-3250-45e4-9c3a-4cfb08ef9c98_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52cae2c-3250-45e4-9c3a-4cfb08ef9c98_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52cae2c-3250-45e4-9c3a-4cfb08ef9c98_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52cae2c-3250-45e4-9c3a-4cfb08ef9c98_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52cae2c-3250-45e4-9c3a-4cfb08ef9c98_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52cae2c-3250-45e4-9c3a-4cfb08ef9c98_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ef458365-a016-45ff-842a-7388a89ed774_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ef458365-a016-45ff-842a-7388a89ed774_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ef458365-a016-45ff-842a-7388a89ed774_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ef458365-a016-45ff-842a-7388a89ed774_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ef458365-a016-45ff-842a-7388a89ed774_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ef458365-a016-45ff-842a-7388a89ed774_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ef458365-a016-45ff-842a-7388a89ed774_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52f9edf-409b-46dc-8d99-b0b6e0e3a336_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52f9edf-409b-46dc-8d99-b0b6e0e3a336_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52f9edf-409b-46dc-8d99-b0b6e0e3a336_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52f9edf-409b-46dc-8d99-b0b6e0e3a336_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52f9edf-409b-46dc-8d99-b0b6e0e3a336_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52f9edf-409b-46dc-8d99-b0b6e0e3a336_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c52f9edf-409b-46dc-8d99-b0b6e0e3a336_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8e4d3ab1-5e08-424f-9146-054314535ad5_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8e4d3ab1-5e08-424f-9146-054314535ad5_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8e4d3ab1-5e08-424f-9146-054314535ad5_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8e4d3ab1-5e08-424f-9146-054314535ad5_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8e4d3ab1-5e08-424f-9146-054314535ad5_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8e4d3ab1-5e08-424f-9146-054314535ad5_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/8e4d3ab1-5e08-424f-9146-054314535ad5_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2311c02-9841-47a0-954a-ff8bbfbd84ba_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2311c02-9841-47a0-954a-ff8bbfbd84ba_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2311c02-9841-47a0-954a-ff8bbfbd84ba_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2311c02-9841-47a0-954a-ff8bbfbd84ba_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2311c02-9841-47a0-954a-ff8bbfbd84ba_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2311c02-9841-47a0-954a-ff8bbfbd84ba_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/c2311c02-9841-47a0-954a-ff8bbfbd84ba_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/72eb0edc-42e6-40b5-b788-39d8dae7f353_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/72eb0edc-42e6-40b5-b788-39d8dae7f353_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/72eb0edc-42e6-40b5-b788-39d8dae7f353_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/72eb0edc-42e6-40b5-b788-39d8dae7f353_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/72eb0edc-42e6-40b5-b788-39d8dae7f353_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/72eb0edc-42e6-40b5-b788-39d8dae7f353_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/72eb0edc-42e6-40b5-b788-39d8dae7f353_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b9d3a42e-caae-49a0-87c0-9e766112ee5d_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b9d3a42e-caae-49a0-87c0-9e766112ee5d_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b9d3a42e-caae-49a0-87c0-9e766112ee5d_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b9d3a42e-caae-49a0-87c0-9e766112ee5d_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b9d3a42e-caae-49a0-87c0-9e766112ee5d_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b9d3a42e-caae-49a0-87c0-9e766112ee5d_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/b9d3a42e-caae-49a0-87c0-9e766112ee5d_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc47f830-9785-4651-9756-cde2f39fb494_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc47f830-9785-4651-9756-cde2f39fb494_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc47f830-9785-4651-9756-cde2f39fb494_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc47f830-9785-4651-9756-cde2f39fb494_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc47f830-9785-4651-9756-cde2f39fb494_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc47f830-9785-4651-9756-cde2f39fb494_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/cc47f830-9785-4651-9756-cde2f39fb494_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/707d9dbf-1621-4eac-a157-1393de750d7b_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/707d9dbf-1621-4eac-a157-1393de750d7b_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/707d9dbf-1621-4eac-a157-1393de750d7b_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/707d9dbf-1621-4eac-a157-1393de750d7b_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/707d9dbf-1621-4eac-a157-1393de750d7b_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/707d9dbf-1621-4eac-a157-1393de750d7b_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/707d9dbf-1621-4eac-a157-1393de750d7b_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/48834369-72f5-4bbb-847c-5636af5a6882_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/48834369-72f5-4bbb-847c-5636af5a6882_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/48834369-72f5-4bbb-847c-5636af5a6882_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/48834369-72f5-4bbb-847c-5636af5a6882_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/48834369-72f5-4bbb-847c-5636af5a6882_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/48834369-72f5-4bbb-847c-5636af5a6882_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/48834369-72f5-4bbb-847c-5636af5a6882_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/62de2524-c400-459b-98a2-746e0ed84eb2_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/62de2524-c400-459b-98a2-746e0ed84eb2_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/62de2524-c400-459b-98a2-746e0ed84eb2_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/62de2524-c400-459b-98a2-746e0ed84eb2_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/62de2524-c400-459b-98a2-746e0ed84eb2_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/62de2524-c400-459b-98a2-746e0ed84eb2_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/62de2524-c400-459b-98a2-746e0ed84eb2_aug_6.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ed3c3ea6-58a4-46d1-8b7c-1c575fb29893_aug_0.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ed3c3ea6-58a4-46d1-8b7c-1c575fb29893_aug_1.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ed3c3ea6-58a4-46d1-8b7c-1c575fb29893_aug_2.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ed3c3ea6-58a4-46d1-8b7c-1c575fb29893_aug_3.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ed3c3ea6-58a4-46d1-8b7c-1c575fb29893_aug_4.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ed3c3ea6-58a4-46d1-8b7c-1c575fb29893_aug_5.pt
# Saved augmented mel-spectrogram at /kaggle/working/mel_spectrograms/augmented_train/ed3c3ea6-58a4-46d1-8b7c-1c575fb29893_aug_6.pt

# %%
output_dir_train_aug = '/kaggle/working/mel_spectrograms/augmented_train'
output_zip_train_aug = '/kaggle/working/mel_spectrograms_augmented_train.zip'
zip_directory(output_dir_train_aug, output_zip_train_aug)
